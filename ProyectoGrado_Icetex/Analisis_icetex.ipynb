# %%
import pandas as pd
#graficos informativos y estadisticos con mejor diseño
import seaborn as sns
#funciones matematicas , algebraicas, vectores y matrices
import numpy as np
#genera diversos tipos de graficos
import matplotlib.pyplot as plt
# %matplotlib inline
#from sklearn.linear_model import LinearRegression   # saber valores optimos
from sklearn import linear_model 
import datetime
from statistics import mean

datos= pd.read_csv ("Cr_ditos_Otorgados_por_ICETEX..csv",sep=",") # lee un archivo separado por comas (,)
print(datos)
datos.hist()
# Out:
#        VIGENCIA PERIODO OTORGAMIENTO SEXO AL NACER  ESTRATO SOCIO ECONÓMICO  \
# 0          2015               2015-1      Femenino                        1
# 1          2015               2015-1      Femenino                        1
# 2          2015               2015-1      Femenino                        1
# 3          2015               2015-1      Femenino                        1
# 4          2015               2015-1      Femenino                        1
# ...         ...                  ...           ...                      ...
# 79604      2022               2022-2     Masculino                        6
# 79605      2022               2022-2     Masculino                        6
# 79606      2022               2022-2     Masculino                        6
# 79607      2022               2022-2     Masculino                        6
# 79608      2022               2022-2     Masculino                        6
#
#        CÓDIGO DEDEPARTAMENTO DE ORIGEN DEPARTAMENTO DE ORIGEN  \
# 0                                    5              ANTIOQUIA
# 1                                    5              ANTIOQUIA
# 2                                    5              ANTIOQUIA
# 3                                    5              ANTIOQUIA
# 4                                    5              ANTIOQUIA
# ...                                ...                    ...
# 79604                               76        VALLE DEL CAUCA
# 79605                               76        VALLE DEL CAUCA
# 79606                               76        VALLE DEL CAUCA
# 79607                               76        VALLE DEL CAUCA
# 79608                               76        VALLE DEL CAUCA
#
#       CATEGORÍA DEL MUNICIPIO DE ORIGEN SECTOR IES  \
# 0             CIUDADES Y AGLOMERACIONES    OFICIAL
# 1             CIUDADES Y AGLOMERACIONES    OFICIAL
# 2             CIUDADES Y AGLOMERACIONES    OFICIAL
# 3             CIUDADES Y AGLOMERACIONES    OFICIAL
# 4             CIUDADES Y AGLOMERACIONES    OFICIAL
# ...                                 ...        ...
# 79604         CIUDADES Y AGLOMERACIONES        NaN
# 79605         CIUDADES Y AGLOMERACIONES    PRIVADO
# 79606         CIUDADES Y AGLOMERACIONES    PRIVADO
# 79607         CIUDADES Y AGLOMERACIONES    PRIVADO
# 79608         CIUDADES Y AGLOMERACIONES    PRIVADO
#
#                       NIVEL DE FORMACIÓN MODALIDAD DE LÍNEA  \
# 0          Formación técnica profesional           PREGRADO
# 1          Formación técnica profesional           PREGRADO
# 2          Formación técnica profesional           PREGRADO
# 3                            Tecnológico           PREGRADO
# 4                          Universitario           PREGRADO
# ...                                  ...                ...
# 79604               Educación continuada   CRÉDITO EXTERIOR
# 79605  Especialización médico quirúrgica      POSGRADO PAÍS
# 79606      Especialización universitaria      POSGRADO PAÍS
# 79607      Especialización universitaria      POSGRADO PAÍS
# 79608                      Universitario           PREGRADO
#
#       MODALIDAD DEL CRÉDITO RANGO DEL VALOR TOTAL DESEMBOLSADO  \
# 0                 MATRICULA                                  I
# 1                 MATRICULA                                 IV
# 2                 MATRICULA                                  V
# 3             SOSTENIMIENTO                                  I
# 4                 MATRICULA                                  I
# ...                     ...                                ...
# 79604             MATRICULA                                III
# 79605             MATRICULA                                  V
# 79606             MATRICULA                                III
# 79607             MATRICULA                                 IV
# 79608             MATRICULA                                  V
#
#        NÚMERO DE NUEVOS BENEFICIARIOS DE CRÉDITO
# 0                                              1
# 1                                              1
# 2                                              2
# 3                                              1
# 4                                              5
# ...                                          ...
# 79604                                          1
# 79605                                          1
# 79606                                          1
# 79607                                          1
# 79608                                          1
#
# [79609 rows x 13 columns]
# array([[<Axes: title={'center': 'VIGENCIA'}>,
#         <Axes: title={'center': 'ESTRATO SOCIO ECONÓMICO'}>],
#        [<Axes: title={'center': 'CÓDIGO DEDEPARTAMENTO DE ORIGEN'}>,
#         <Axes: title={'center': 'NÚMERO DE NUEVOS BENEFICIARIOS DE CRÉDITO'}>]],
#       dtype=object)

# %%
pythonic_machine_ages = datos["NÚMERO DE NUEVOS BENEFICIARIOS DE CRÉDITO"]

media=(mean(pythonic_machine_ages))
media=(str(media))
print("El valor de la media de los nuevos beneficiarios es: "+media)
# Out:
# El valor de la media de los nuevos beneficiarios es: 4.789835320127121

# %%
resultado = datos['NÚMERO DE NUEVOS BENEFICIARIOS DE CRÉDITO'].sum()
print("La suma total de los nuevos beneficiarios es: "+str(resultado))
# Out:
# La suma total de los nuevos beneficiarios es: 381314

# %%
datos= pd.read_csv ("Cr_ditos_Otorgados_por_ICETEX..csv",sep=",")
departamento="CÓDIGO DEDEPARTAMENTO DE ORIGEN"
estrato="ESTRATO SOCIO ECONÓMICO"

df3 = datos[[departamento, estrato, "VIGENCIA"]]
print(df3)
#agrupado = datos.groupby(["CÓDIGO DEDEPARTAMENTO DE ORIGEN", "ESTRATO SOCIO ECONÓMICO"])["CÓDIGO DEDEPARTAMENTO DE ORIGEN"]==1.["ESTRATO SOCIO ECONÓMICO"]==5
#print(agrupado)

#print (df3[df3.estrato>1])

#print (df3[df3.votes>200000])
#print (df3[(df3.departamento==5) & (df3.estrato==1)])
# Out:
#        CÓDIGO DEDEPARTAMENTO DE ORIGEN  ESTRATO SOCIO ECONÓMICO  VIGENCIA
# 0                                    5                        1      2015
# 1                                    5                        1      2015
# 2                                    5                        1      2015
# 3                                    5                        1      2015
# 4                                    5                        1      2015
# ...                                ...                      ...       ...
# 79604                               76                        6      2022
# 79605                               76                        6      2022
# 79606                               76                        6      2022
# 79607                               76                        6      2022
# 79608                               76                        6      2022
#
# [79609 rows x 3 columns]

# %%
survey_sub = datos.head(10)
print(survey_sub)
# Out:
#    VIGENCIA PERIODO OTORGAMIENTO SEXO AL NACER  ESTRATO SOCIO ECONÓMICO  \
# 0      2015               2015-1      Femenino                        1
# 1      2015               2015-1      Femenino                        1
# 2      2015               2015-1      Femenino                        1
# 3      2015               2015-1      Femenino                        1
# 4      2015               2015-1      Femenino                        1
# 5      2015               2015-1      Femenino                        1
# 6      2015               2015-1      Femenino                        1
# 7      2015               2015-1      Femenino                        1
# 8      2015               2015-1      Femenino                        1
# 9      2015               2015-1      Femenino                        1
#
#    CÓDIGO DEDEPARTAMENTO DE ORIGEN DEPARTAMENTO DE ORIGEN  \
# 0                                5              ANTIOQUIA
# 1                                5              ANTIOQUIA
# 2                                5              ANTIOQUIA
# 3                                5              ANTIOQUIA
# 4                                5              ANTIOQUIA
# 5                                5              ANTIOQUIA
# 6                                5              ANTIOQUIA
# 7                                5              ANTIOQUIA
# 8                                5              ANTIOQUIA
# 9                                5              ANTIOQUIA
#
#   CATEGORÍA DEL MUNICIPIO DE ORIGEN SECTOR IES             NIVEL DE FORMACIÓN  \
# 0         CIUDADES Y AGLOMERACIONES    OFICIAL  Formación técnica profesional
# 1         CIUDADES Y AGLOMERACIONES    OFICIAL  Formación técnica profesional
# 2         CIUDADES Y AGLOMERACIONES    OFICIAL  Formación técnica profesional
# 3         CIUDADES Y AGLOMERACIONES    OFICIAL                    Tecnológico
# 4         CIUDADES Y AGLOMERACIONES    OFICIAL                  Universitario
# 5         CIUDADES Y AGLOMERACIONES    OFICIAL                  Universitario
# 6         CIUDADES Y AGLOMERACIONES    OFICIAL                  Universitario
# 7         CIUDADES Y AGLOMERACIONES    PRIVADO                    Tecnológico
# 8         CIUDADES Y AGLOMERACIONES    PRIVADO                    Tecnológico
# 9         CIUDADES Y AGLOMERACIONES    PRIVADO                    Tecnológico
#
#   MODALIDAD DE LÍNEA MODALIDAD DEL CRÉDITO RANGO DEL VALOR TOTAL DESEMBOLSADO  \
# 0           PREGRADO             MATRICULA                                  I
# 1           PREGRADO             MATRICULA                                 IV
# 2           PREGRADO             MATRICULA                                  V
# 3           PREGRADO         SOSTENIMIENTO                                  I
# 4           PREGRADO             MATRICULA                                  I
# 5           PREGRADO         SOSTENIMIENTO                                  I
# 6           PREGRADO         SOSTENIMIENTO                                III
# 7           PREGRADO             MATRICULA                                  I
# 8           PREGRADO             MATRICULA                                 II
# 9           PREGRADO             MATRICULA                                III
#
#    NÚMERO DE NUEVOS BENEFICIARIOS DE CRÉDITO
# 0                                          1
# 1                                          1
# 2                                          2
# 3                                          1
# 4                                          5
# 5                                          2
# 6                                         13
# 7                                          1
# 8                                          4
# 9                                          3
